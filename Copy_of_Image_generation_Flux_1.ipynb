# %% [markdown]
# <a href="https://colab.research.google.com/github/tohver/AI-LLM-Engineering-Notebooks/blob/main/Copy_of_Image_generation_Flux_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q diffusers transformers accelerate bitsandbytes datasets fsspec==2023.9.2

# %%
from huggingface_hub import login
from google.colab import userdata


hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
import torch
from diffusers import FluxPipeline

pipe = FluxPipeline.from_pretrained("black-forest-labs/FLUX.1-schnell", torch_dtype=torch.bfloat16).to("cuda")
generator = torch.Generator(device="cuda").manual_seed(0)
prompt = "A cat holding a sign that says hello world"

# Generate the image using the GPU
image = pipe(
    prompt,
    guidance_scale=0.0,
    num_inference_steps=4,
    max_sequence_length=256,
    generator=generator
).images[0]

image.save("surreal.png")
# Out:
# model_index.json:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Fetching 23 files:   0%|          | 0/23 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/782 [00:00<?, ?B/s]
# text_encoder_2/model-00002-of-00002.safe(…):   0%|          | 0.00/4.53G [00:00<?, ?B/s]
# text_encoder/model.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# text_encoder_2/model-00001-of-00002.safe(…):   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/19.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# ...
